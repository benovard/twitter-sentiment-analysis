# %%
"""Plots data in an interactive matplotlib plot"""
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from ipywidgets import widgets, interactive

# %%
df = pd.read_csv('../tweet_data/matrix_data.csv', header=0)

# %%
select1 = widgets.Dropdown(
    options=list(df.columns),
    description='first keyword'
)

select2 = widgets.Dropdown(
    options=list(df.columns),
    description='second keyword'
)

# %%
import matplotlib.dates as mdates
myFmt = mdates.DateFormatter('%d')

# %%
def plot(select1, select2):

    ax = plt.gca()
    #ax.xaxis_date()
    #ax.xaxis.set_major_formatter(myFmt)
    df.plot(kind='line', x='date', y=select1, ax=ax)
    df.plot(kind='line', x='date', y=select2, ax=ax)
    plt.axhline(color='black')
    plt.ylim((-1, 1))
    plt.show()

# %%
interactive(plot, select1=select1, select2=select2)
# Out:
# interactive(children=(Dropdown(description='first keyword', index=1, options=('date', 'climate change', 'coal'…
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~/miniconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in _fetch_figure_metadata(fig)
#     175         # the background is transparent
#     176         ticksLight = _is_light([label.get_color()
# --> 177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
# ...
